# %%
txt = "When I glance over my notes and records of the Sherlock Holmes cases between the years '82 and '90, I am faced by so"

x = txt.split()


from urllib import response
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(stop_words='english')
response = vectorizer.fit_transform(x)
features = vectorizer.get_feature_names()

print(features)
# Out:
# ['82', '90', 'cases', 'faced', 'glance', 'holmes', 'notes', 'records', 'sherlock', 'years']

# %%
f=open("orange.txt","r")
data = f.read().splitlines()
print(data)
f.close()
# Out:
# [':.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:', "         -----=====Earth's Dreamlands=====-----", '           (313)558-5024 {14.4} (313)558-5517', '              A BBS for text file junkies', '              RPGNet GM File Archive Site', '.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.', '', '                The Five Orange Pips', '', '  When I glance over my notes and records of the Sherlock', "Holmes cases between the years '82 and '90, I am faced by so", 'many which present strange and interesting features that it is no', 'easy matter to know which to choose and which to leave. Some,', 'however, have already gained publicity through the papers, and', 'others have not offered a field for those peculiar qualities which', 'my friend possessed in so high a degree, and which it is the', 'object of these papers to illustrate. Some, too, have baffled his', 'analytical skill, and would be, as narratives, beginnings without', 'an ending, while others have be
# ...

# %%
f=open("orange.txt","r")
data = f.read().split()
datas = f.read().splitlines()



from urllib import response
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(stop_words='english')
response = vectorizer.fit_transform(data)
features = vectorizer.get_feature_names()
print(datas)
print("")
print(features)
print("")
print("hasil")

print(response)
# Out:
# []
#
# ...

# %%
f=open("orange.txt","r")
data = f.read().splitlines()



from urllib import response
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
response = vectorizer.fit_transform(datas)
features = vectorizer.get_feature_names()
print(data)
print("")
print("hasil")

print(response)
# Out:
# [':.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:', "         -----=====Earth's Dreamlands=====-----", '           (313)558-5024 {14.4} (313)558-5517', '              A BBS for text file junkies', '              RPGNet GM File Archive Site', '.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.:.', '', '                The Five Orange Pips', '', '  When I glance over my notes and records of the Sherlock', "Holmes cases between the years '82 and '90, I am faced by so", 'many which present strange and interesting features that it is no', 'easy matter to know which to choose and which to leave. Some,', 'however, have already gained publicity through the papers, and', 'others have not offered a field for those peculiar qualities which', 'my friend possessed in so high a degree, and which it is the', 'object of these papers to illustrate. Some, too, have baffled his', 'analytical skill, and would be, as narratives, beginnings without', 'an ending, while others have be
# ...
